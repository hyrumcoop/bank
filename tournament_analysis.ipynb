# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('./results.csv')

# %%
roundsof10 = df[df['roundsPerGame'] == 10]
roundsof10
# Out:
#            playerName  roundsPerGame  playersPerTable  winsV1/2PlayersPlayer  \
# 0   LastBankingPlayer             10                3                    533
# 1        200PotPlayer             10                3                    431
# 2       1000PotPlayer             10                3                    500
# 3        7RollsPlayer             10                3                    405
# 4       14RollsPlayer             10                3                    485
# ..                ...            ...              ...                    ...
# 79   1/12RandomPlayer             10                9                   2678
# 80     3DoublesPlayer             10                9                   1459
# 81     7DoublesPlayer             10                9                   1298
# 82  AdversarialLeader             10                9                   3541
# 83   1/2PlayersPlayer             10                9                   5486
#
# ...
